# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-5bb1021a1e11> in <module>
#       3 import seaborn as sns
#       4 import pandas as pd
# ----> 5 pwd
#
# NameError: name 'pwd' is not defined

# %%
df = pd.read_csv('C:\\Users\\prabp\\Downloads\\archive (4)\\Walmart.csv')

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Day'] = df['Date'].dt.weekday
df['Month'] = df['Date'].dt.month
df['Year']  = df['Date'].dt.year
df.drop('Date',axis=1,inplace=True)
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Day  Month  Year
# 0         8.106    6      5  2010
# 1         8.106    3     12  2010
# 2         8.106    4      2  2010
# 3         8.106    4      2  2010
# 4         8.106    0      5  2010

# %%
days = {0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5: 'Friday',6:'Saturday'}
df['Day'] = df['Day'].map(days)
months={1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'Novemenber',12:'December'}
df['Month']= df['Month'].map(months)
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment        Day     Month  Year
# 0         8.106   Saturday       May  2010
# 1         8.106  Wednesday  December  2010
# 2         8.106   Thursday  February  2010
# 3         8.106   Thursday  February  2010
# 4         8.106     Sunday       May  2010

# %%
tge= {'Sunday':5,'Monday':3, 'Tuesday':0, 'Wednesday':4, 'Thursday':6,  'Friday':1,'Saturday':2}
df['Day'] = df['Day'].map(tge)
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Day     Month  Year
# 0         8.106    2       May  2010
# 1         8.106    4  December  2010
# 2         8.106    6  February  2010
# 3         8.106    6  February  2010
# 4         8.106    5       May  2010

# %%
yr = {2010:1, 2011:2, 2012:0}
df['Year'] = df['Year'].map(yr)
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Day     Month  Year
# 0         8.106    2       May     1
# 1         8.106    4  December     1
# 2         8.106    6  February     1
# 3         8.106    6  February     1
# 4         8.106    5       May     1

# %%
mn = {'January':1,'February':3,'March':4,'April':12,'May':11,'June':6,'July':8,'August':5,'September':7,'October':10,'Novemenber':2,'December':9}
df['Month'] = df['Month'].map(mn)
df.head()
# Out:
#    Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0      1    1643690.90             0        42.31       2.572  211.096358
# 1      1    1641957.44             1        38.51       2.548  211.242170
# 2      1    1611968.17             0        39.93       2.514  211.289143
# 3      1    1409727.59             0        46.63       2.561  211.319643
# 4      1    1554806.68             0        46.50       2.625  211.350143
#
#    Unemployment  Day  Month  Year
# 0         8.106    2     11     1
# 1         8.106    4      9     1
# 2         8.106    6      3     1
# 3         8.106    6      3     1
# 4         8.106    5     11     1

# %%
last_column = df.pop('Weekly_Sales')

# %%
df.insert(9, 'Weekly_Sales',last_column ,allow_duplicates = False)

# %%
df
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 0         1             0        42.31       2.572  211.096358         8.106
# 1         1             1        38.51       2.548  211.242170         8.106
# 2         1             0        39.93       2.514  211.289143         8.106
# 3         1             0        46.63       2.561  211.319643         8.106
# 4         1             0        46.50       2.625  211.350143         8.106
# ...     ...           ...          ...         ...         ...           ...
# 6430     45             0        64.88       3.997  192.013558         8.684
# 6431     45             0        64.89       3.985  192.170412         8.667
# 6432     45             0        54.47       4.000  192.327265         8.667
# 6433     45             0        56.47       3.969  192.330854         8.667
# 6434     45             0        58.85       3.882  192.308899         8.667
#
#       Day  Month  Year  Weekly_Sales
# 0       2     11     1    1643690.90
# 1       4      9     1    1641957.44
# 2       6      3     1    1611968.17
# 3       6      3     1    1409727.59
# 4       5     11     1    1554806.68
# ...   ...    ...   ...           ...
# 6430    6      7     0     713173.95
# 6431    4     11     0     733455.07
# 6432    5      9     0     734464.36
# 6433    6     10     0     718125.53
# 6434    6     10     0     760281.43
#
# [6435 rows x 10 columns]

# %%
X = df.iloc[:,:-1]
X.shape
# Out:
# (6435, 9)

# %%
Y =df.iloc[:,-1]
Y.shape
# Out:
# (6435,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.4,random_state=42)

# %%
X_train.shape
# Out:
# (3861, 9)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
transformer = ColumnTransformer(transformers=[('tf',OneHotEncoder(sparse=False,drop='first'),['Store'])],remainder='passthrough')

# %%
X_train= transformer.fit_transform(X_train)
X_test = transformer.transform(X_test)

# %%
X_train.shape
# Out:
# (3861, 52)

# %%
X_test.shape
# Out:
# (2574, 52)

# %%
X_train
# Out:
# array([[ 0.,  0.,  0., ...,  6.,  5.,  2.],
#        [ 0.,  1.,  0., ...,  4., 10.,  2.],
#        [ 0.,  0.,  0., ...,  1.,  2.,  1.],
#        ...,
#        [ 0.,  0.,  0., ...,  2., 11.,  2.],
#        [ 0.,  0.,  0., ...,  6.,  9.,  2.],
#        [ 0.,  0.,  0., ...,  6.,  3.,  1.]])

# %%
df
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 0         1             0        42.31       2.572  211.096358         8.106
# 1         1             1        38.51       2.548  211.242170         8.106
# 2         1             0        39.93       2.514  211.289143         8.106
# 3         1             0        46.63       2.561  211.319643         8.106
# 4         1             0        46.50       2.625  211.350143         8.106
# ...     ...           ...          ...         ...         ...           ...
# 6430     45             0        64.88       3.997  192.013558         8.684
# 6431     45             0        64.89       3.985  192.170412         8.667
# 6432     45             0        54.47       4.000  192.327265         8.667
# 6433     45             0        56.47       3.969  192.330854         8.667
# 6434     45             0        58.85       3.882  192.308899         8.667
#
#       Day  Month  Year  Weekly_Sales
# 0       2     11     1    1643690.90
# 1       4      9     1    1641957.44
# 2       6      3     1    1611968.17
# 3       6      3     1    1409727.59
# 4       5     11     1    1554806.68
# ...   ...    ...   ...           ...
# 6430    6      7     0     713173.95
# 6431    4     11     0     733455.07
# 6432    5      9     0     734464.36
# 6433    6     10     0     718125.53
# 6434    6     10     0     760281.43
#
# [6435 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
def pred_model(model,X_train,Y_train,X_test,Y_test):
    c = model()
    c.fit(X_train,Y_train)
    y_pred = c.predict(X_test)
    print(model)
    print(f'MSE: {mean_squared_error(Y_test,y_pred)}')
    print(f'MAE: {mean_absolute_error(Y_test,y_pred)}')
    print(f'R2 : {r2_score(Y_test,y_pred)}')
    




pred_model(LinearRegression,X_train,Y_train,X_test,Y_test)
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
# MSE: 25913530442.619396
# MAE: 94445.49920330281
# R2 : 0.9184356055757809

# %%
import time
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LassoLarsIC
from sklearn.pipeline import make_pipeline

start_time = time.time()
lasso_lars_ic = make_pipeline(
    StandardScaler(), LassoLarsIC(criterion="aic", normalize=False)
).fit(X_train, Y_train)
fit_time = time.time() - start_time

# %%
results = pd.DataFrame(
    {
        "alphas": lasso_lars_ic[-1].alphas_,
        "AIC criterion": lasso_lars_ic[-1].criterion_,
    }
).set_index("alphas")
alpha_aic = lasso_lars_ic[-1].alpha_

# %%
lasso_lars_ic.set_params(lassolarsic__criterion="bic").fit(X_train, Y_train)
results["BIC criterion"] = lasso_lars_ic[-1].criterion_
alpha_bic = lasso_lars_ic[-1].alpha_

# %%
def highlight_min(x):
    x_min = x.min()
    return ["font-weight: bold" if v == x_min else "" for v in x]


results.style.apply(highlight_min)
# Out:
# <style  type="text/css" >
# #T_5ed38_row52_col1,#T_5ed38_row66_col0{
#             font-weight:  bold;
#         }</style><table id="T_5ed38_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AIC criterion</th>        <th class="col_heading level0 col1" >BIC criterion</th>    </tr>    <tr>        <th class="index_name level0" >alphas</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5ed38_level0_row0" class="row_heading level0 row0" >166817.5578375079</th>
#                         <td id="T_5ed38_row0_col0" class="data row0 col0" >3861.000000</td>
#                         <td id="T_5ed38_row0_col1" class="data row0 col1" >3861.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row1" class="row_heading level0 row1" >153794.00834522396</th>
#                         <td id="T_5ed38_row1_col0" class="data row1 col0" >3812.436146</td>
#                         <td id="T_5ed38_row1_col1" class="data row1 col1" >3818.694828</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row2" class="row_heading level0 row2" >152629.4654786539</th>
#                         <td id="T_5ed38_row2_col0" class="data row2 col0" >3805.597585</td>
#                         <td id="T_5ed38_row2_col1" class="data row2 col1" >3818.114948</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row3" class="row_heading level0 row3" >144394.02252085585</th>
#                         <td id="T_5ed38_row3_col0" class="data row3 col0" >3714.480588</td>
#                         <td id="T_5ed38_row3_col1" class="data row3 col1" >3733.256633</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row4" class="row_heading level0 row4" >133268.1718978638</th>
#                         <td id="T_5ed38_row4_col0" class="data row4 col0" >3555.844052</td>
#                         <td id="T_5ed38_row4_col1" class="data row4 col1" >3580.878778</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row5" class="row_heading level0 row5" >130066.53438489449</th>
#                         <td id="T_5ed38_row5_col0" class="data row5 col0" >3501.764296</td>
#                         <td id="T_5ed38_row5_col1" class="data row5 col1" >3533.057703</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row6" class="row_heading level0 row6" >122207.5202562995</th>
#                         <td id="T_5ed38_row6_col0" class="data row6 col0" >3341.667623</td>
#                         <td id="T_5ed38_row6_col1" class="data row6 col1" >3379.219712</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row7" class="row_heading level0 row7" >105239.78160481909</th>
#                         <td id="T_5ed38_row7_col0" class="data row7 col0" >2965.499609</td>
#                         <td id="T_5ed38_row7_col1" class="data row7 col1" >3009.310379</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row8" class="row_heading level0 row8" >105112.5958315477</th>
#                         <td id="T_5ed38_row8_col0" class="data row8 col0" >2964.661521</td>
#                         <td id="T_5ed38_row8_col1" class="data row8 col1" >3014.730973</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row9" class="row_heading level0 row9" >102633.24029315518</th>
#                         <td id="T_5ed38_row9_col0" class="data row9 col0" >2907.518107</td>
#                         <td id="T_5ed38_row9_col1" class="data row9 col1" >2963.846241</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row10" class="row_heading level0 row10" >92139.63074749496</th>
#                         <td id="T_5ed38_row10_col0" class="data row10 col0" >2656.402497</td>
#                         <td id="T_5ed38_row10_col1" class="data row10 col1" >2718.989312</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row11" class="row_heading level0 row11" >90918.5099858404</th>
#                         <td id="T_5ed38_row11_col0" class="data row11 col0" >2628.577953</td>
#                         <td id="T_5ed38_row11_col1" class="data row11 col1" >2697.423450</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row12" class="row_heading level0 row12" >85443.40232807843</th>
#                         <td id="T_5ed38_row12_col0" class="data row12 col0" >2491.952943</td>
#                         <td id="T_5ed38_row12_col1" class="data row12 col1" >2567.057121</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row13" class="row_heading level0 row13" >85220.966035856</th>
#                         <td id="T_5ed38_row13_col0" class="data row13 col0" >2488.095848</td>
#                         <td id="T_5ed38_row13_col1" class="data row13 col1" >2569.458708</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row14" class="row_heading level0 row14" >79041.31358076412</th>
#                         <td id="T_5ed38_row14_col0" class="data row14 col0" >2320.338351</td>
#                         <td id="T_5ed38_row14_col1" class="data row14 col1" >2407.959892</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row15" class="row_heading level0 row15" >73411.36612090583</th>
#                         <td id="T_5ed38_row15_col0" class="data row15 col0" >2169.488430</td>
#                         <td id="T_5ed38_row15_col1" class="data row15 col1" >2263.368652</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row16" class="row_heading level0 row16" >70789.29826256204</th>
#                         <td id="T_5ed38_row16_col0" class="data row16 col0" >2099.193291</td>
#                         <td id="T_5ed38_row16_col1" class="data row16 col1" >2199.332195</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row17" class="row_heading level0 row17" >70707.03374817304</th>
#                         <td id="T_5ed38_row17_col0" class="data row17 col0" >2098.844375</td>
#                         <td id="T_5ed38_row17_col1" class="data row17 col1" >2205.241960</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row18" class="row_heading level0 row18" >69644.33334458063</th>
#                         <td id="T_5ed38_row18_col0" class="data row18 col0" >2069.053208</td>
#                         <td id="T_5ed38_row18_col1" class="data row18 col1" >2181.709475</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row19" class="row_heading level0 row19" >69048.88303547693</th>
#                         <td id="T_5ed38_row19_col0" class="data row19 col0" >2052.433842</td>
#                         <td id="T_5ed38_row19_col1" class="data row19 col1" >2171.348790</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row20" class="row_heading level0 row20" >65360.90197514448</th>
#                         <td id="T_5ed38_row20_col0" class="data row20 col0" >1937.026796</td>
#                         <td id="T_5ed38_row20_col1" class="data row20 col1" >2062.200426</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row21" class="row_heading level0 row21" >65111.75172978398</th>
#                         <td id="T_5ed38_row21_col0" class="data row21 col0" >1930.923025</td>
#                         <td id="T_5ed38_row21_col1" class="data row21 col1" >2062.355337</td>
#             </tr>
#             <tr>
#                         <th id="T_5ed38_level0_row22" class="row_heading level0 row22" >63496.215811810885</th>
#                         <td id="T_5ed38_row22_col0" class="data row22 col0" >1878.300405</td>

# %%
ax = results.plot()
ax.vlines(
    alpha_aic,
    results["AIC criterion"].min(),
    results["AIC criterion"].max(),
    label="alpha: AIC estimate",
    linestyles="--",
    color="tab:blue",
)
ax.vlines(
    alpha_bic,
    results["BIC criterion"].min(),
    results["BIC criterion"].max(),
    label="alpha: BIC estimate",
    linestyle="--",
    color="tab:orange",
)
ax.set_xlabel(r"$\alpha$")
ax.set_ylabel("criterion")
ax.set_xscale("log")
ax.legend()
_ = ax.set_title(
    f"Information-criterion for model selection (training time {fit_time:.2f}s)"
)

# %%
sns.pairplot(df,kind='scatter')

# %%
import numpy as np
df.hist(column = 'Store',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Store'}>]], dtype=object)

# %%
df.hist(column = 'Holiday_Flag',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Holiday_Flag'}>]], dtype=object)

# %%
df.hist(column = 'Temperature',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Temperature'}>]], dtype=object)

# %%
df.hist(column = 'Fuel_Price',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Fuel_Price'}>]], dtype=object)

# %%
df.hist(column = 'CPI',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'CPI'}>]], dtype=object)

# %%
df.hist(column = 'Unemployment',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Unemployment'}>]], dtype=object)

# %%
df.hist(column = 'Day',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Day'}>]], dtype=object)

# %%
df.hist(column = 'Month',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Month'}>]], dtype=object)

# %%
df.hist(column = 'Year',xlabelsize =10)
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>]], dtype=object)

# %%
df.corr(method = 'pearson')
# Out:
#                      Store  Holiday_Flag  Temperature  Fuel_Price       CPI  \
# Store         1.000000e+00 -4.386841e-16    -0.022659    0.060023 -0.209492
# Holiday_Flag -4.386841e-16  1.000000e+00    -0.155091   -0.078347 -0.002162
# Temperature  -2.265908e-02 -1.550913e-01     1.000000    0.144982  0.176888
# Fuel_Price    6.002295e-02 -7.834652e-02     0.144982    1.000000 -0.170642
# CPI          -2.094919e-01 -2.162091e-03     0.176888   -0.170642  1.000000
# Unemployment  2.235313e-01  1.096028e-02     0.101158   -0.034684 -0.302020
# Day           5.096433e-15 -1.279040e-01     0.003406    0.151046  0.016561
# Month        -4.424855e-16 -2.028131e-03     0.096680    0.063542 -0.001633
# Year          3.135062e-15  4.624865e-02    -0.099397   -0.084899 -0.037234
# Weekly_Sales -3.353320e-01  3.689097e-02    -0.063810    0.009464 -0.072634
#
#               Unemployment           Day         Month          Year  \
# Store             0.223531  5.096433e-15 -4.424855e-16  3.135062e-15
# Holiday_Flag      0.010960 -1.279040e-01 -2.028131e-03  4.624865e-02
# Temperature       0.101158  3.406346e-03  9.668034e-02 -9.939717e-02
# Fuel_Price       -0.034684  1.510461e-01  6.354202e-02 -8.489903e-02
# CPI              -0.302020  1.656071e-02 -1.633427e-03 -3.723376e-02
# Unemployment      1.000000 -5.272722e-02  3.288266e-03  1.482339e-01
# Day              -0.052727  1.000000e+00  1.820081e-02 -1.738656e-01
# Month             0.003288  1.820081e-02  1.000000e+00  3.978053e-03
# Year              0.148234 -1.738656e-01  3.978053e-03  1.000000e+00
# Weekly_Sales     -0.106176 -1.038403e-02  9.790919e-03  8.148511e-03
#
#               Weekly_Sales
# Store            -0.335332
# Holiday_Flag      0.036891
# Temperature      -0.063810
# Fuel_Price        0.009464
# CPI              -0.072634
# Unemployment     -0.106176
# Day              -0.010384
# Month             0.009791
# Year              0.008149
# Weekly_Sales      1.000000

# %%
df.plot.scatter('Temperature','Weekly_Sales')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Weekly_Sales'>

# %%
df.plot.scatter('Fuel_Price','Weekly_Sales')
# Out:
# <AxesSubplot:xlabel='Fuel_Price', ylabel='Weekly_Sales'>

# %%
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
X2 = sm.add_constant(X)
est = sm.OLS(Y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Weekly_Sales   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.141
# Method:                 Least Squares   F-statistic:                     118.0
# Date:                Fri, 30 Sep 2022   Prob (F-statistic):          6.70e-206
# Time:                        16:39:31   Log-Likelihood:                -93860.
# No. Observations:                6435   AIC:                         1.877e+05
# Df Residuals:                    6425   BIC:                         1.878e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.989e+06   7.81e+04     25.468      0.000    1.84e+06    2.14e+06
# Store        -1.537e+04    522.211    -29.441      0.000   -1.64e+04   -1.44e+04
# Holiday_Flag  7.011e+04   2.61e+04      2.682      0.007    1.89e+04    1.21e+05
# Temperature   -995.9156    380.265     -2.619      0.009   -1741.361    -250.470
# Fuel_Price    1.084e+04    1.5e+04      0.722      0.470   -1.86e+04    4.02e+04
# CPI          -2314.3579    184.977    -12.512      0.000   -2676.975   -1951.741
# Unemployment -2.232e+04   3835.956     -5.818      0.000   -2.98e+04   -1.48e+04
# Day          -2693.0412   4202.221     -0.641      0.522   -1.09e+04    5544.712
# Month         2077.5941   1928.568      1.077      0.281   -1703.042    5858.230
# Year          5417.0836   8304.597      0.652      0.514   -1.09e+04    2.17e+04
# ==============================================================================
# Omnibus:                      187.390   Durbin-Watson:                   0.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              203.409
# Skew:                           0.433   Prob(JB):                     6.77e-45
# Kurtosis:                       3.096   Cond. No.                     2.27e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.27e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
